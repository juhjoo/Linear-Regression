# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Salary_Data.csv')

# %%
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset.plot()

# %%
dataset.plot(x='YearsExperience', y='Salary')

# %%
dataset.plot.scatter(x='YearsExperience', y='Salary')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = dataset['YearsExperience'].values.reshape(-1, 1)
y = dataset['Salary'].values
bias_vector = np.ones((m, 1))
x_reshape = np.append(bias_vector, x, axis=1)

# %%
x_transpose = np.transpose(x_reshape)
x_transpose
x_transpose_dot_x = x_transpose.dot(x)
x_transpose_dot_x
# Out:
# array([ 159.4, 1080.5])

# %%
x_inv = np.linalg.inv(x_transpose_dot_x)
x_inv
# Out:
# array([[ 0.15421086, -0.02274985],
#        [-0.02274985,  0.00428165]])

# %%
y_temp = x_transpose.dot(y)
y_temp
# Out:
# array([ 2280090., 14321961.])

# %%
theta = x_inv.dot(y_temp)
theta
# Out:
# array([25792.20019867,  9449.96232146])

# %%
theta[0]
# Out:
# 25792.200198668696

# %%
theta[1]
# Out:
# 9449.962321455081
